# %%
# Battery
CA55 : COMA
Nombre d'epochs: 128
Nombre de canaux: 126
Fréquence d'échantillonnage: 500.0 Hz
Fenêtre temporelle: -0.200 à 1.000 s
Durée d'une epoch: 1.200 s

NOMBRE DE POINTS TEMPORELS: 601
Résolution temporelle: 2.00 ms

  AP/1/Music/Conv/D/V1      : 3171 (  3 epochs)
  AP/1/Music/Conv/D/V2      : 3181 (  1 epochs)
  AP/1/Music/Conv/D/V3      : 3191 (  3 epochs)
  AP/1/Music/Conv/G/V1      : 3141 (  2 epochs)
  AP/1/Music/Conv/G/V2      : 3151 (  0 epochs)
  AP/1/Music/Conv/G/V3      : 3161 (  2 epochs)
  AP/2/Music/Conv/D/V1      : 3172 (  3 epochs)
  AP/2/Music/Conv/D/V2      : 3182 (  3 epochs)
  AP/2/Music/Conv/D/V3      : 3192 (  3 epochs)
  AP/2/Music/Conv/G/V1      : 3142 (  3 epochs)
  AP/2/Music/Conv/G/V2      : 3152 (  1 epochs)
  AP/2/Music/Conv/G/V3      : 3162 (  2 epochs)
  AP/3/Music/Conv/D/V1      : 3173 (  2 epochs)
  AP/3/Music/Conv/D/V2      : 3183 (  4 epochs)
  AP/3/Music/Conv/D/V3      : 3193 (  1 epochs)
  AP/3/Music/Conv/G/V1      : 3143 (  1 epochs)
  AP/3/Music/Conv/G/V2      : 3153 (  2 epochs)
  AP/3/Music/Conv/G/V3      : 3163 (  2 epochs)
  AP/4/Music/Conv/D/V1      : 3174 (  2 epochs)
  AP/4/Music/Conv/D/V2      : 3184 (  1 epochs)
  AP/4/Music/Conv/D/V3      : 3194 (  2 epochs)
  AP/4/Music/Conv/G/V1      : 3144 (  2 epochs)
  AP/4/Music/Conv/G/V2      : 3154 (  2 epochs)
  AP/4/Music/Conv/G/V3      : 3164 (  2 epochs)
  AP/5/Music/Conv/D/V1      : 3175 (  1 epochs)
  AP/5/Music/Conv/D/V2      : 3185 (  2 epochs)
  AP/5/Music/Conv/D/V3      : 3195 (  2 epochs)
  AP/5/Music/Conv/G/V1      : 3145 (  2 epochs)
  AP/5/Music/Conv/G/V2      : 3155 (  1 epochs)
  AP/5/Music/Conv/G/V3      : 3165 (  1 epochs)
  AP/6/Music/Conv/D/V1      : 3176 (  1 epochs)
  AP/6/Music/Conv/D/V2      : 3186 (  0 epochs)
  AP/6/Music/Conv/D/V3      : 3196 (  1 epochs)
  AP/6/Music/Conv/G/V1      : 3146 (  2 epochs)
  AP/6/Music/Conv/G/V2      : 3156 (  0 epochs)
  AP/6/Music/Conv/G/V3      : 3166 (  3 epochs)
  PP/Music/Conv/D/V1        : 1170 ( 11 epochs)
  PP/Music/Conv/D/V2        : 1180 ( 12 epochs)
  PP/Music/Conv/D/V3        : 1190 ( 12 epochs)
  PP/Music/Conv/G/V1        : 1140 ( 12 epochs)
  PP/Music/Conv/G/V2        : 1150 (  5 epochs)
  PP/Music/Conv/G/V3        : 1160 ( 11 epochs)

AP/1: 11
AP/2: 15
AP/3: 12
AP/4: 11
AP/5: 9
AP/6: 7
PP: 63

# %%
#PPext3 : COMA : CS38
Nombre d'epochs: 278
Nombre de canaux: 126
Fréquence d'échantillonnage: 500.0 Hz
Fenêtre temporelle: -0.200 à 1.000 s
Durée d'une epoch: 1.200 s

NOMBRE DE POINTS TEMPORELS: 601
Résolution temporelle: 2.00 ms
  AP/1/Music/Conv/D/V1      : 3171 (  3 epochs)
  AP/1/Music/Conv/D/V2      : 3181 (  1 epochs)
  AP/1/Music/Conv/D/V3      : 3191 (  0 epochs)
  AP/1/Music/Conv/G/V1      : 3141 (  0 epochs)
  AP/1/Music/Conv/G/V2      : 3151 (  1 epochs)
  AP/1/Music/Conv/G/V3      : 3161 (  1 epochs)
  AP/1/Music/Dio/V1         : 3111 (  3 epochs)
  AP/1/Music/Dio/V2         : 3121 (  1 epochs)
  AP/1/Music/Dio/V3         : 3131 (  3 epochs)
  AP/1/Noise/Conv/D/V1      : 2171 (  1 epochs)
  AP/1/Noise/Conv/D/V2      : 2181 (  2 epochs)
  AP/1/Noise/Conv/D/V3      : 2191 (  0 epochs)
  AP/1/Noise/Conv/G/V1      : 2141 (  0 epochs)
  AP/1/Noise/Conv/G/V2      : 2151 (  2 epochs)
  AP/1/Noise/Conv/G/V3      : 2161 (  2 epochs)
  AP/1/Noise/Dio/V1         : 2111 (  3 epochs)
  AP/1/Noise/Dio/V2         : 2121 (  0 epochs)
  AP/1/Noise/Dio/V3         : 2131 (  3 epochs)
  AP/2/Music/Conv/D/V1      : 3172 (  2 epochs)
  AP/2/Music/Conv/D/V2      : 3182 (  2 epochs)
  AP/2/Music/Conv/D/V3      : 3192 (  0 epochs)
  AP/2/Music/Conv/G/V1      : 3142 (  0 epochs)
  AP/2/Music/Conv/G/V2      : 3152 (  1 epochs)
  AP/2/Music/Conv/G/V3      : 3162 (  2 epochs)
  AP/2/Music/Dio/V1         : 3112 (  2 epochs)
  AP/2/Music/Dio/V2         : 3122 (  2 epochs)
  AP/2/Music/Dio/V3         : 3132 (  3 epochs)
  AP/2/Noise/Conv/D/V1      : 2172 (  3 epochs)
  AP/2/Noise/Conv/D/V2      : 2182 (  1 epochs)
  AP/2/Noise/Conv/D/V3      : 2192 (  0 epochs)
  AP/2/Noise/Conv/G/V1      : 2142 (  0 epochs)
  AP/2/Noise/Conv/G/V2      : 2152 (  1 epochs)
  AP/2/Noise/Conv/G/V3      : 2162 (  0 epochs)
  AP/2/Noise/Dio/V1         : 2112 (  0 epochs)
  AP/2/Noise/Dio/V2         : 2122 (  2 epochs)
  AP/2/Noise/Dio/V3         : 2132 (  2 epochs)
  AP/3/Music/Conv/D/V1      : 3173 (  0 epochs)
  AP/3/Music/Conv/D/V2      : 3183 (  0 epochs)
  AP/3/Music/Conv/D/V3      : 3193 (  0 epochs)
  AP/3/Music/Conv/G/V1      : 3143 (  0 epochs)
  AP/3/Music/Conv/G/V2      : 3153 (  1 epochs)
  AP/3/Music/Conv/G/V3      : 3163 (  1 epochs)
  AP/3/Music/Dio/V1         : 3113 (  2 epochs)
  AP/3/Music/Dio/V2         : 3123 (  1 epochs)
  AP/3/Music/Dio/V3         : 3133 (  2 epochs)
  AP/3/Noise/Conv/D/V1      : 2173 (  0 epochs)
  AP/3/Noise/Conv/D/V2      : 2183 (  1 epochs)
  AP/3/Noise/Conv/D/V3      : 2193 (  0 epochs)
  AP/3/Noise/Conv/G/V1      : 2143 (  0 epochs)
  AP/3/Noise/Conv/G/V2      : 2153 (  0 epochs)
  AP/3/Noise/Conv/G/V3      : 2163 (  3 epochs)
  AP/3/Noise/Dio/V1         : 2113 (  2 epochs)
  AP/3/Noise/Dio/V2         : 2123 (  2 epochs)
  AP/3/Noise/Dio/V3         : 2133 (  2 epochs)
  AP/4/Music/Conv/D/V1      : 3174 (  2 epochs)
  AP/4/Music/Conv/D/V2      : 3184 (  1 epochs)
  AP/4/Music/Conv/D/V3      : 3194 (  0 epochs)
  AP/4/Music/Conv/G/V1      : 3144 (  0 epochs)
  AP/4/Music/Conv/G/V2      : 3154 (  0 epochs)
  AP/4/Music/Conv/G/V3      : 3164 (  3 epochs)
  AP/4/Music/Dio/V1         : 3114 (  0 epochs)
  AP/4/Music/Dio/V2         : 3124 (  3 epochs)
  AP/4/Music/Dio/V3         : 3134 (  3 epochs)
  AP/4/Noise/Conv/D/V1      : 2174 (  1 epochs)
  AP/4/Noise/Conv/D/V2      : 2184 (  2 epochs)
  AP/4/Noise/Conv/D/V3      : 2194 (  0 epochs)
  AP/4/Noise/Conv/G/V1      : 2144 (  0 epochs)
  AP/4/Noise/Conv/G/V2      : 2154 (  0 epochs)
  AP/4/Noise/Conv/G/V3      : 2164 (  1 epochs)
  AP/4/Noise/Dio/V1         : 2114 (  1 epochs)
  AP/4/Noise/Dio/V2         : 2124 (  3 epochs)
  AP/4/Noise/Dio/V3         : 2134 (  2 epochs)
  AP/5/Music/Conv/D/V1      : 3175 (  0 epochs)
  AP/5/Music/Conv/D/V2      : 3185 (  2 epochs)
  AP/5/Music/Conv/D/V3      : 3195 (  0 epochs)
  AP/5/Music/Conv/G/V1      : 3145 (  0 epochs)
  AP/5/Music/Conv/G/V2      : 3155 (  2 epochs)
  AP/5/Music/Conv/G/V3      : 3165 (  2 epochs)
  AP/5/Music/Dio/V1         : 3115 (  4 epochs)
  AP/5/Music/Dio/V2         : 3125 (  2 epochs)
  AP/5/Music/Dio/V3         : 3135 (  0 epochs)
  AP/5/Noise/Conv/D/V1      : 2175 (  2 epochs)
  AP/5/Noise/Conv/D/V2      : 2185 (  0 epochs)
  AP/5/Noise/Conv/D/V3      : 2195 (  0 epochs)
  AP/5/Noise/Conv/G/V1      : 2145 (  0 epochs)
  AP/5/Noise/Conv/G/V2      : 2155 (  1 epochs)
  AP/5/Noise/Conv/G/V3      : 2165 (  0 epochs)
  AP/5/Noise/Dio/V1         : 2115 (  2 epochs)
  AP/5/Noise/Dio/V2         : 2125 (  1 epochs)
  AP/5/Noise/Dio/V3         : 2135 (  0 epochs)
  AP/6/Music/Conv/D/V1      : 3176 (  4 epochs)
  AP/6/Music/Conv/D/V2      : 3186 (  0 epochs)
  AP/6/Music/Conv/D/V3      : 3196 (  0 epochs)
  AP/6/Music/Conv/G/V1      : 3146 (  0 epochs)
  AP/6/Music/Conv/G/V2      : 3156 (  1 epochs)
  AP/6/Music/Conv/G/V3      : 3166 (  3 epochs)
  AP/6/Music/Dio/V1         : 3116 (  1 epochs)
  AP/6/Music/Dio/V2         : 3126 (  3 epochs)
  AP/6/Music/Dio/V3         : 3136 (  1 epochs)
  AP/6/Noise/Conv/D/V1      : 2176 (  3 epochs)
  AP/6/Noise/Conv/D/V2      : 2186 (  0 epochs)
  AP/6/Noise/Conv/D/V3      : 2196 (  0 epochs)
  AP/6/Noise/Conv/G/V1      : 2146 (  0 epochs)
  AP/6/Noise/Conv/G/V2      : 2156 (  2 epochs)
  AP/6/Noise/Conv/G/V3      : 2166 (  6 epochs)
  AP/6/Noise/Dio/V1         : 2116 (  4 epochs)
  AP/6/Noise/Dio/V2         : 2126 (  2 epochs)
  AP/6/Noise/Dio/V3         : 2136 (  2 epochs)
  PP/Music/Conv/D/V1        : 1170 ( 11 epochs)
  PP/Music/Conv/D/V2        : 1180 (  6 epochs)
  PP/Music/Conv/D/V3        : 1190 (  0 epochs)
  PP/Music/Conv/G/V1        : 1140 (  0 epochs)
  PP/Music/Conv/G/V2        : 1150 (  6 epochs)
  PP/Music/Conv/G/V3        : 1160 ( 12 epochs)
  PP/Music/Dio/V1           : 1110 ( 11 epochs)
  PP/Music/Dio/V2           : 1120 ( 12 epochs)
  PP/Music/Dio/V3           : 1130 ( 11 epochs)
  PP/Noise/Conv/D/V1        : 170 ( 12 epochs)
  PP/Noise/Conv/D/V2        : 180 (  6 epochs)
  PP/Noise/Conv/D/V3        : 190 (  0 epochs)
  PP/Noise/Conv/G/V1        : 140 (  0 epochs)
  PP/Noise/Conv/G/V2        : 150 (  6 epochs)
  PP/Noise/Conv/G/V3        : 160 ( 12 epochs)
  PP/Noise/Dio/V1           : 110 ( 12 epochs)
  PP/Noise/Dio/V2           : 120 ( 11 epochs)
  PP/Noise/Dio/V3           : 130 ( 12 epochs)

AP Music/Conv/D : 17
AP Music/Conv/G : 18
AP Music/Dio : 34
PP Noise/Conv/D : 18
PP Noise/Conv/G : 18
PP Noise/Dio : 35

# %%
# P01 : VG PPmusic : 
Nombre d'epochs: 144
Nombre de canaux: 15
Fréquence d'échantillonnage: 256.0 Hz
Fenêtre temporelle: -0.199 à 1.000 s
Durée d'une epoch: 1.199 s

NOMBRE DE POINTS TEMPORELS: 308
Résolution temporelle: 3.91 ms

EVENT_ID DICTIONARY:
----------------------------------------
  AP/Music/2                : 102 (  3 epochs)
  AP/Music/3                : 103 (  3 epochs)
  AP/Music/4                : 104 (  4 epochs)
  AP/Music/5                : 105 (  3 epochs)
  AP/Music/6                : 106 (  8 epochs)
  AP/Music/7                : 107 (  8 epochs)
  AP/Music/8                : 108 (  7 epochs)
  AP/Noise/2                : 112 (  3 epochs)
  AP/Noise/3                : 113 (  3 epochs)
  AP/Noise/4                : 114 (  8 epochs)
  AP/Noise/5                : 115 (  5 epochs)
  AP/Noise/6                : 116 (  3 epochs)
  AP/Noise/7                : 117 (  8 epochs)
  AP/Noise/8                : 118 (  4 epochs)
  PP/Music                  :   1 ( 38 epochs)
  PP/Noise                  :  11 ( 36 epochs)

# %%
# DELIRIUM (cat del)
RÉSUMÉ DU FICHIER: TpAB19_PP_preproc_noICA_PP-epo_ar.fif
================================================================================
Nombre d'epochs: 320
Nombre de canaux: 126
Fréquence d'échantillonnage: 500.0 Hz
Fenêtre temporelle: -0.200 à 1.000 s
Durée d'une epoch: 1.200 s

NOMBRE DE POINTS TEMPORELS: 601
Résolution temporelle: 2.00 ms

EVENT_ID DICTIONARY:
----------------------------------------
  AP/11                     : 111 ( 16 epochs)
  AP/12                     : 112 ( 14 epochs)
  AP/13                     : 113 ( 16 epochs)
  AP/14                     : 114 ( 16 epochs)
  AP/15                     : 115 ( 16 epochs)
  AP/16                     : 116 ( 16 epochs)
  AP/21                     : 121 ( 14 epochs)
  AP/22                     : 122 ( 15 epochs)
  AP/23                     : 123 ( 15 epochs)
  AP/24                     : 124 ( 12 epochs)
  AP/25                     : 125 ( 14 epochs)
  AP/26                     : 126 ( 13 epochs)
  AP/31                     : 131 ( 10 epochs)
  AP/32                     : 132 ( 17 epochs)
  AP/33                     : 133 ( 15 epochs)
  AP/34                     : 134 ( 20 epochs)
  AP/35                     : 135 ( 17 epochs)
  AP/36                     : 136 ( 20 epochs)
  PP/10                     : 110 ( 13 epochs)
  PP/20                     : 120 ( 17 epochs)
  PP/30                     : 130 ( 14 epochs)
